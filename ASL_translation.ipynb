# %% [markdown]
# # 1. Import and Install Dependencies

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    # Define face connections manually or use predefined connections
    face_connections = mp_holistic.FACEMESH_TESSELATION
    mp_drawing.draw_landmarks(image, results.face_landmarks, face_connections) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    face_connections = mp_holistic.FACEMESH_TESSELATION
    mp_drawing.draw_landmarks(image, results.face_landmarks, face_connections, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.49394292,  0.46338305, -0.61690193, ...,  0.        ,
#         0.        ,  0.        ])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.49394292,  0.46338305, -0.61690193, ...,  0.        ,
#         0.        ,  0.        ])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array([' ', 'Hello!', 'Thanks', 'I love you'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 30

# %%
for action in actions: 
    # dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
                print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results) 
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen 
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718286735.363227       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ...
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {' ': 0, 'Hello!': 1, 'Thanks': 2, 'I love you': 3}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (120, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (120,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (120, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (6, 4)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=1000, callbacks=[tb_callback])
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 2s 42ms/step - loss: 18.5381 - categorical_accuracy: 0.2982
# Epoch 2/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 187.6562 - categorical_accuracy: 0.3246
# Epoch 3/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 154.5963 - categorical_accuracy: 0.3421
# Epoch 4/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 124.2870 - categorical_accuracy: 0.2456
# Epoch 5/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 103.5725 - categorical_accuracy: 0.2895
# Epoch 6/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 119.1188 - categorical_accuracy: 0.2807
# Epoch 7/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 188.5769 - categorical_accuracy: 0.2807
# Epoch 8/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 368.8048 - categorical_accuracy: 0.2456
# Epoch 9/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 461.5178 - categorical_accuracy: 0.1228
# Epoch 10/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 483.0524 - categorical_accuracy: 0.2018
# Epoch 11/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 491.3083 - categorical_accuracy: 0.2719
# Epoch 12/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 428.2803 - categorical_accuracy: 0.2544
# Epoch 13/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 3131.1836 - categorical_accuracy: 0.2632
# Epoch 14/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 2373.9890 - categorical_accuracy: 0.3070
# Epoch 15/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 3592.2947 - categorical_accuracy: 0.2281
# Epoch 16/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 2578.0291 - categorical_accuracy: 0.2281
# Epoch 17/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 1992.0469 - categorical_accuracy: 0.1842
# Epoch 18/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 677.4102 - categorical_accuracy: 0.3772
# Epoch 19/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1810.0922 - categorical_accuracy: 0.2544
# Epoch 20/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 1374.9435 - categorical_accuracy: 0.2632
# Epoch 21/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 1351.4419 - categorical_accuracy: 0.2895
# Epoch 22/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 1226.8558 - categorical_accuracy: 0.3333
# Epoch 23/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 764.7562 - categorical_accuracy: 0.2281
# Epoch 24/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 1191.9919 - categorical_accuracy: 0.2895
# Epoch 25/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 779.4070 - categorical_accuracy: 0.2807
# Epoch 26/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 1142.4346 - categorical_accuracy: 0.2281
# Epoch 27/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 1028.2417 - categorical_accuracy: 0.2544
# Epoch 28/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 1012.6841 - categorical_accuracy: 0.2632
# Epoch 29/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 578.9152 - categorical_accuracy: 0.2544
# Epoch 30/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 838.3339 - categorical_accuracy: 0.2807
# Epoch 31/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 633.7126 - categorical_accuracy: 0.2018
# Epoch 32/1000
# 4/4 [==============================] - 0s 66ms/step - loss: 361.3470 - categorical_accuracy: 0.2632
# Epoch 33/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 201.4288 - categorical_accuracy: 0.2456
# Epoch 34/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 377.7547 - categorical_accuracy: 0.2456
# Epoch 35/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 268.5797 - categorical_accuracy: 0.2368
# Epoch 36/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 363.5817 - categorical_accuracy: 0.2193
# Epoch 37/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 428.4394 - categorical_accuracy: 0.2193
# Epoch 38/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 565.7536 - categorical_accuracy: 0.2719
# Epoch 39/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 593.9305 - categorical_accuracy: 0.2982
# Epoch 40/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 815.4630 - categorical_accuracy: 0.2982
# Epoch 41/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 570.1025 - categorical_accuracy: 0.2719
# Epoch 42/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 517.4691 - categorical_accuracy: 0.2368
# Epoch 43/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 756.3661 - categorical_accuracy: 0.2281
# Epoch 44/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 429.4666 - categorical_accuracy: 0.2281
# Epoch 45/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 337.5323 - categorical_accuracy: 0.2632
# Epoch 46/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 404.3443 - categorical_accuracy: 0.2456
# Epoch 47/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 291.7598 - categorical_accuracy: 0.2719
# Epoch 48/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 270.2791 - categorical_accuracy: 0.2719
# Epoch 49/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 207.8281 - categorical_accuracy: 0.2018
# Epoch 50/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 595.7280 - categorical_accuracy: 0.2368
# Epoch 51/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 605.8547 - categorical_accuracy: 0.2193
# Epoch 52/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 359.6230 - categorical_accuracy: 0.2895
# Epoch 53/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 594.5884 - categorical_accuracy: 0.2544
# Epoch 54/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 472.4299 - categorical_accuracy: 0.2632
# Epoch 55/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 516.4112 - categorical_accuracy: 0.2456
# Epoch 56/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 487.9815 - categorical_accuracy: 0.2895
# Epoch 57/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 377.4862 - categorical_accuracy: 0.2456
# Epoch 58/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 265.1324 - categorical_accuracy: 0.1491
# Epoch 59/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 224.4169 - categorical_accuracy: 0.2368
# Epoch 60/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 352.7212 - categorical_accuracy: 0.2456
# Epoch 61/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 127.8126 - categorical_accuracy: 0.2018
# Epoch 62/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 182.2503 - categorical_accuracy: 0.2982
# Epoch 63/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 209.7588 - categorical_accuracy: 0.2544
# Epoch 64/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 114.2676 - categorical_accuracy: 0.3333
# Epoch 65/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 175.3805 - categorical_accuracy: 0.1667
# Epoch 66/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 198.9503 - categorical_accuracy: 0.2193
# Epoch 67/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 112.9667 - categorical_accuracy: 0.2193
# Epoch 68/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 200.3793 - categorical_accuracy: 0.2544
# Epoch 69/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 301.8396 - categorical_accuracy: 0.3070
# Epoch 70/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 278.6605 - categorical_accuracy: 0.2719
# Epoch 71/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 472.5652 - categorical_accuracy: 0.2456
# Epoch 72/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 355.9600 - categorical_accuracy: 0.2368
# Epoch 73/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 338.2927 - categorical_accuracy: 0.3070
# Epoch 74/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 317.6198 - categorical_accuracy: 0.2193
# Epoch 75/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 292.8075 - categorical_accuracy: 0.2807
# Epoch 76/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 330.8542 - categorical_accuracy: 0.2544
# Epoch 77/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 238.5819 - categorical_accuracy: 0.2982
# Epoch 78/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 177.4151 - categorical_accuracy: 0.3333
# Epoch 79/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 164.2565 - categorical_accuracy: 0.2632
# Epoch 80/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 308.1641 - categorical_accuracy: 0.2719
# Epoch 81/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 321.1646 - categorical_accuracy: 0.2456
# Epoch 82/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 432.0023 - categorical_accuracy: 0.2719
# Epoch 83/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 431.6866 - categorical_accuracy: 0.1754
# Epoch 84/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 302.6051 - categorical_accuracy: 0.2105
# Epoch 85/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 397.2662 - categorical_accuracy: 0.2368
# Epoch 86/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 311.1941 - categorical_accuracy: 0.2895
# Epoch 87/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 371.4871 - categorical_accuracy: 0.2982
# Epoch 88/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 173.3305 - categorical_accuracy: 0.2719
# Epoch 89/1000
# 4/4 [==============================] - 0s 69ms/step - loss: 285.2108 - categorical_accuracy: 0.2018
# Epoch 90/1000
# 4/4 [==============================] - 0s 57ms/step - loss: 288.1050 - categorical_accuracy: 0.2193
# Epoch 91/1000
# 4/4 [==============================] - 0s 57ms/step - loss: 331.0185 - categorical_accuracy: 0.2368
# Epoch 92/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 158.3014 - categorical_accuracy: 0.2807
# Epoch 93/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 168.3275 - categorical_accuracy: 0.2544
# Epoch 94/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 275.4161 - categorical_accuracy: 0.1930
# Epoch 95/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 242.7191 - categorical_accuracy: 0.2544
# Epoch 96/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 220.4156 - categorical_accuracy: 0.2895
# Epoch 97/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 224.4285 - categorical_accuracy: 0.1930
# Epoch 98/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 70.7415 - categorical_accuracy: 0.2895
# Epoch 99/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 204.8724 - categorical_accuracy: 0.2018
# Epoch 100/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 219.2527 - categorical_accuracy: 0.2807
# Epoch 101/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 149.3422 - categorical_accuracy: 0.2193
# Epoch 102/1000
# 4/4 [==============================] - 0s 57ms/step - loss: 135.0753 - categorical_accuracy: 0.3246
# Epoch 103/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 134.0829 - categorical_accuracy: 0.2895
# Epoch 104/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 113.1480 - categorical_accuracy: 0.2982
# Epoch 105/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 348.1971 - categorical_accuracy: 0.2632
# Epoch 106/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 230.1668 - categorical_accuracy: 0.2544
# Epoch 107/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 181.6758 - categorical_accuracy: 0.2807
# Epoch 108/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 168.5194 - categorical_accuracy: 0.2281
# Epoch 109/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 271.5940 - categorical_accuracy: 0.2544
# Epoch 110/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 240.9798 - categorical_accuracy: 0.2544
# Epoch 111/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 318.5373 - categorical_accuracy: 0.3070
# Epoch 112/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 163.1435 - categorical_accuracy: 0.2544
# Epoch 113/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 295.8954 - categorical_accuracy: 0.2807
# Epoch 114/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 163.6074 - categorical_accuracy: 0.2544
# Epoch 115/1000
# 4/4 [==============================] - 0s 57ms/step - loss: 223.2115 - categorical_accuracy: 0.2719
# Epoch 116/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 150.1301 - categorical_accuracy: 0.1754
# Epoch 117/1000
# 4/4 [==============================] - 0s 69ms/step - loss: 283.2419 - categorical_accuracy: 0.2456
# Epoch 118/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 183.2502 - categorical_accuracy: 0.1842
# Epoch 119/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 340.3964 - categorical_accuracy: 0.2719
# Epoch 120/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 207.7339 - categorical_accuracy: 0.1667
# Epoch 121/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 102.6157 - categorical_accuracy: 0.2632
# Epoch 122/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 87.7639 - categorical_accuracy: 0.2105
# Epoch 123/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 70.3327 - categorical_accuracy: 0.1930
# Epoch 124/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 68.8544 - categorical_accuracy: 0.2368
# Epoch 125/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 84.1727 - categorical_accuracy: 0.2544
# Epoch 126/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 132.0590 - categorical_accuracy: 0.2719
# Epoch 127/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 125.6241 - categorical_accuracy: 0.2105
# Epoch 128/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 253.3632 - categorical_accuracy: 0.2632
# Epoch 129/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 243.4224 - categorical_accuracy: 0.2544
# Epoch 130/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 101.1524 - categorical_accuracy: 0.2719
# Epoch 131/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 152.3791 - categorical_accuracy: 0.2807
# Epoch 132/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 170.4506 - categorical_accuracy: 0.2456
# Epoch 133/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 187.0765 - categorical_accuracy: 0.2544
# Epoch 134/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 164.8748 - categorical_accuracy: 0.2895
# Epoch 135/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 174.0662 - categorical_accuracy: 0.2018
# Epoch 136/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 93.4702 - categorical_accuracy: 0.3509
# Epoch 137/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 143.1287 - categorical_accuracy: 0.3421
# Epoch 138/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 128.4874 - categorical_accuracy: 0.2105
# Epoch 139/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 120.7805 - categorical_accuracy: 0.1842
# Epoch 140/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 91.6407 - categorical_accuracy: 0.2368
# Epoch 141/1000
# 4/4 [==============================] - 0s 57ms/step - loss: 62.4577 - categorical_accuracy: 0.2807
# Epoch 142/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 124.1063 - categorical_accuracy: 0.2895
# Epoch 143/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 141.3997 - categorical_accuracy: 0.2456
# Epoch 144/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 135.2313 - categorical_accuracy: 0.2281
# Epoch 145/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 189.0913 - categorical_accuracy: 0.2368
# Epoch 146/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 115.0577 - categorical_accuracy: 0.2544
# Epoch 147/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 182.4902 - categorical_accuracy: 0.2193
# Epoch 148/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 121.7501 - categorical_accuracy: 0.2719
# Epoch 149/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 96.5605 - categorical_accuracy: 0.2456
# Epoch 150/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 99.0666 - categorical_accuracy: 0.2281
# Epoch 151/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 139.1633 - categorical_accuracy: 0.2544
# Epoch 152/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 164.5370 - categorical_accuracy: 0.2544
# Epoch 153/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 131.8999 - categorical_accuracy: 0.2632
# Epoch 154/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 73.6128 - categorical_accuracy: 0.1754
# Epoch 155/1000
# 4/4 [==============================] - 0s 57ms/step - loss: 92.9131 - categorical_accuracy: 0.2632
# Epoch 156/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 90.7391 - categorical_accuracy: 0.2368
# Epoch 157/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 135.8681 - categorical_accuracy: 0.2105
# Epoch 158/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 220.4590 - categorical_accuracy: 0.2368
# Epoch 159/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 416.2734 - categorical_accuracy: 0.2719
# Epoch 160/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 377.4894 - categorical_accuracy: 0.2368
# Epoch 161/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 250.4818 - categorical_accuracy: 0.2895
# Epoch 162/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 348.9348 - categorical_accuracy: 0.2456
# Epoch 163/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 235.0559 - categorical_accuracy: 0.2456
# Epoch 164/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 138.3106 - categorical_accuracy: 0.2456
# Epoch 165/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 253.6221 - categorical_accuracy: 0.2193
# Epoch 166/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 224.2983 - categorical_accuracy: 0.2632
# Epoch 167/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 256.7884 - categorical_accuracy: 0.3947
# Epoch 168/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1336.2212 - categorical_accuracy: 0.2105
# Epoch 169/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 1114.9546 - categorical_accuracy: 0.2281
# Epoch 170/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 400.6251 - categorical_accuracy: 0.1754
# Epoch 171/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 158.2050 - categorical_accuracy: 0.2456
# Epoch 172/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 180.2107 - categorical_accuracy: 0.2105
# Epoch 173/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 181.0830 - categorical_accuracy: 0.2632
# Epoch 174/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 137.3494 - categorical_accuracy: 0.2193
# Epoch 175/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 193.4406 - categorical_accuracy: 0.2632
# Epoch 176/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 194.8793 - categorical_accuracy: 0.3684
# Epoch 177/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 199.1500 - categorical_accuracy: 0.2982
# Epoch 178/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 132.2170 - categorical_accuracy: 0.2544
# Epoch 179/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 140.4049 - categorical_accuracy: 0.2544
# Epoch 180/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 136.0748 - categorical_accuracy: 0.3947
# Epoch 181/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 97.9673 - categorical_accuracy: 0.2368
# Epoch 182/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 118.2102 - categorical_accuracy: 0.1228
# Epoch 183/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 116.6593 - categorical_accuracy: 0.2281
# Epoch 184/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 148.9638 - categorical_accuracy: 0.2193
# Epoch 185/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 142.1569 - categorical_accuracy: 0.2281
# Epoch 186/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 214.0237 - categorical_accuracy: 0.2105
# Epoch 187/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 167.2542 - categorical_accuracy: 0.2895
# Epoch 188/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 106.7270 - categorical_accuracy: 0.2719
# Epoch 189/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 189.6928 - categorical_accuracy: 0.2719
# Epoch 190/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 158.4126 - categorical_accuracy: 0.2895
# Epoch 191/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 137.7945 - categorical_accuracy: 0.2719
# Epoch 192/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 122.9083 - categorical_accuracy: 0.2632
# Epoch 193/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 153.8880 - categorical_accuracy: 0.2193
# Epoch 194/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 91.6008 - categorical_accuracy: 0.2456
# Epoch 195/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 67.3314 - categorical_accuracy: 0.3070
# Epoch 196/1000
# 4/4 [==============================] - 0s 71ms/step - loss: 77.8680 - categorical_accuracy: 0.2544
# Epoch 197/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 50.4293 - categorical_accuracy: 0.3596
# Epoch 198/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 67.6599 - categorical_accuracy: 0.2544
# Epoch 199/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 24.8375 - categorical_accuracy: 0.3421
# Epoch 200/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 46.0372 - categorical_accuracy: 0.2368
# Epoch 201/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 66.0661 - categorical_accuracy: 0.2281
# Epoch 202/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 129.5696 - categorical_accuracy: 0.2544
# Epoch 203/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 53.7961 - categorical_accuracy: 0.3860
# Epoch 204/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 62.5491 - categorical_accuracy: 0.4035
# Epoch 205/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 60.1335 - categorical_accuracy: 0.1754
# Epoch 206/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 44.4884 - categorical_accuracy: 0.3070
# Epoch 207/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 77.6158 - categorical_accuracy: 0.2807
# Epoch 208/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 67.3168 - categorical_accuracy: 0.2544
# Epoch 209/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 61.8992 - categorical_accuracy: 0.3421
# Epoch 210/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 65.4330 - categorical_accuracy: 0.2544
# Epoch 211/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 35.1129 - categorical_accuracy: 0.3421
# Epoch 212/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 64.3596 - categorical_accuracy: 0.2807
# Epoch 213/1000
# 4/4 [==============================] - 0s 57ms/step - loss: 30.0811 - categorical_accuracy: 0.2544
# Epoch 214/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 43.2747 - categorical_accuracy: 0.4912
# Epoch 215/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 13.3803 - categorical_accuracy: 0.3158
# Epoch 216/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 21.0823 - categorical_accuracy: 0.3070
# Epoch 217/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 12.4131 - categorical_accuracy: 0.4298
# Epoch 218/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 12.3742 - categorical_accuracy: 0.5088
# Epoch 219/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 15.8331 - categorical_accuracy: 0.3684
# Epoch 220/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 28.5404 - categorical_accuracy: 0.4123
# Epoch 221/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 21.0317 - categorical_accuracy: 0.3860
# Epoch 222/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 24.0038 - categorical_accuracy: 0.2719
# Epoch 223/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 12.8600 - categorical_accuracy: 0.4474
# Epoch 224/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 38.2841 - categorical_accuracy: 0.3246
# Epoch 225/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 23.8381 - categorical_accuracy: 0.3772
# Epoch 226/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 25.8482 - categorical_accuracy: 0.3684
# Epoch 227/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 25.7628 - categorical_accuracy: 0.3421
# Epoch 228/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 35.6791 - categorical_accuracy: 0.1930
# Epoch 229/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 1066.7186 - categorical_accuracy: 0.2281
# Epoch 230/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1384.2250 - categorical_accuracy: 0.2544
# Epoch 231/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1059.3842 - categorical_accuracy: 0.3070
# Epoch 232/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 966.4759 - categorical_accuracy: 0.2456
# Epoch 233/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 573.6595 - categorical_accuracy: 0.2105
# Epoch 234/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 439.7122 - categorical_accuracy: 0.2105
# Epoch 235/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 4025.4072 - categorical_accuracy: 0.1930
# Epoch 236/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 6659.9077 - categorical_accuracy: 0.2807
# Epoch 237/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 4300.9658 - categorical_accuracy: 0.2807
# Epoch 238/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 4356.7578 - categorical_accuracy: 0.2456
# Epoch 239/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 5715.3159 - categorical_accuracy: 0.2719
# Epoch 240/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 1781.1686 - categorical_accuracy: 0.3509
# Epoch 241/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 955.8947 - categorical_accuracy: 0.2632
# Epoch 242/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 1378.8706 - categorical_accuracy: 0.2368
# Epoch 243/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1152.1890 - categorical_accuracy: 0.2544
# Epoch 244/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 2066.8479 - categorical_accuracy: 0.2632
# Epoch 245/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 3763.0269 - categorical_accuracy: 0.2632
# Epoch 246/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 3591.8408 - categorical_accuracy: 0.2544
# Epoch 247/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1371.4564 - categorical_accuracy: 0.2719
# Epoch 248/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 2140.1602 - categorical_accuracy: 0.1579
# Epoch 249/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 1611.6987 - categorical_accuracy: 0.2632
# Epoch 250/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 1247.7864 - categorical_accuracy: 0.3246
# Epoch 251/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 1540.9159 - categorical_accuracy: 0.2105
# Epoch 252/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 1064.0272 - categorical_accuracy: 0.2895
# Epoch 253/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1555.2755 - categorical_accuracy: 0.2105
# Epoch 254/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 720.3332 - categorical_accuracy: 0.2456
# Epoch 255/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 258.2225 - categorical_accuracy: 0.2544
# Epoch 256/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 119.6137 - categorical_accuracy: 0.2544
# Epoch 257/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 38.5951 - categorical_accuracy: 0.2456
# Epoch 258/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 24.6997 - categorical_accuracy: 0.2456
# Epoch 259/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 18.7679 - categorical_accuracy: 0.2456
# Epoch 260/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 12.1915 - categorical_accuracy: 0.2456
# Epoch 261/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 2.3671 - categorical_accuracy: 0.2544
# Epoch 262/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 1.6131 - categorical_accuracy: 0.2281
# Epoch 263/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 1.5049 - categorical_accuracy: 0.2456
# Epoch 264/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 1.5111 - categorical_accuracy: 0.2456
# Epoch 265/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 1.4921 - categorical_accuracy: 0.2456
# Epoch 266/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1.4487 - categorical_accuracy: 0.2456
# Epoch 267/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1.4313 - categorical_accuracy: 0.2456
# Epoch 268/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 1.4171 - categorical_accuracy: 0.2456
# Epoch 269/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 1.4095 - categorical_accuracy: 0.2456
# Epoch 270/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.4060 - categorical_accuracy: 0.2456
# Epoch 271/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.3970 - categorical_accuracy: 0.2456
# Epoch 272/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 1.3887 - categorical_accuracy: 0.2456
# Epoch 273/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.3780 - categorical_accuracy: 0.2456
# Epoch 274/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 1.3618 - categorical_accuracy: 0.2456
# Epoch 275/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 1.3429 - categorical_accuracy: 0.3158
# Epoch 276/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 1.3912 - categorical_accuracy: 0.2544
# Epoch 277/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 1.3919 - categorical_accuracy: 0.2544
# Epoch 278/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 1.3919 - categorical_accuracy: 0.2544
# Epoch 279/1000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.3918 - categorical_accuracy: 0.2544
# Epoch 280/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1.3917 - categorical_accuracy: 0.2544
# Epoch 281/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.3915 - categorical_accuracy: 0.2544
# Epoch 282/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 1.3912 - categorical_accuracy: 0.2544
# Epoch 283/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 1.3910 - categorical_accuracy: 0.2544
# Epoch 284/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 1.3663 - categorical_accuracy: 0.2544
# Epoch 285/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 1.3420 - categorical_accuracy: 0.2456
# Epoch 286/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.3255 - categorical_accuracy: 0.2456
# Epoch 287/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1.3098 - categorical_accuracy: 0.2456
# Epoch 288/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.3011 - categorical_accuracy: 0.2456
# Epoch 289/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.2968 - categorical_accuracy: 0.2456
# Epoch 290/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.2927 - categorical_accuracy: 0.2544
# Epoch 291/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 1.2875 - categorical_accuracy: 0.2456
# Epoch 292/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 1.2830 - categorical_accuracy: 0.2456
# Epoch 293/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 1.2794 - categorical_accuracy: 0.2456
# Epoch 294/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 1.2765 - categorical_accuracy: 0.2456
# Epoch 295/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.2734 - categorical_accuracy: 0.2456
# Epoch 296/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.2705 - categorical_accuracy: 0.2456
# Epoch 297/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.2679 - categorical_accuracy: 0.2456
# Epoch 298/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.2646 - categorical_accuracy: 0.2544
# Epoch 299/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 1.2625 - categorical_accuracy: 0.2456
# Epoch 300/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 1.2567 - categorical_accuracy: 0.2456
# Epoch 301/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 1.2514 - categorical_accuracy: 0.2456
# Epoch 302/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 1.2512 - categorical_accuracy: 0.2456
# Epoch 303/1000
# 4/4 [==============================] - 0s 70ms/step - loss: 1.2438 - categorical_accuracy: 0.4035
# Epoch 304/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 1.2418 - categorical_accuracy: 0.5000
# Epoch 305/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 1.2363 - categorical_accuracy: 0.5000
# Epoch 306/1000
# 4/4 [==============================] - 0s 67ms/step - loss: 1.2335 - categorical_accuracy: 0.5000
# Epoch 307/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.2334 - categorical_accuracy: 0.4912
# Epoch 308/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.2282 - categorical_accuracy: 0.4912
# Epoch 309/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 1.2241 - categorical_accuracy: 0.5000
# Epoch 310/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1.2198 - categorical_accuracy: 0.5000
# Epoch 311/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.2159 - categorical_accuracy: 0.5000
# Epoch 312/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 1.2099 - categorical_accuracy: 0.4912
# Epoch 313/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.2043 - categorical_accuracy: 0.5000
# Epoch 314/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 1.2030 - categorical_accuracy: 0.5000
# Epoch 315/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 1.1961 - categorical_accuracy: 0.5088
# Epoch 316/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 1.1902 - categorical_accuracy: 0.4912
# Epoch 317/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 1.1839 - categorical_accuracy: 0.4912
# Epoch 318/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 1.1759 - categorical_accuracy: 0.5000
# Epoch 319/1000
# 4/4 [==============================] - 0s 57ms/step - loss: 1.1761 - categorical_accuracy: 0.5000
# Epoch 320/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 1.1648 - categorical_accuracy: 0.5263
# Epoch 321/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.1508 - categorical_accuracy: 0.5000
# Epoch 322/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.1424 - categorical_accuracy: 0.5702
# Epoch 323/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 1.1380 - categorical_accuracy: 0.5439
# Epoch 324/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 1.1330 - categorical_accuracy: 0.5000
# Epoch 325/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 1.2174 - categorical_accuracy: 0.5351
# Epoch 326/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 1.3935 - categorical_accuracy: 0.4912
# Epoch 327/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.3979 - categorical_accuracy: 0.4561
# Epoch 328/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.3506 - categorical_accuracy: 0.4386
# Epoch 329/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1.3805 - categorical_accuracy: 0.4211
# Epoch 330/1000
# 4/4 [==============================] - 0s 71ms/step - loss: 1.4385 - categorical_accuracy: 0.3509
# Epoch 331/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 1007.2797 - categorical_accuracy: 0.2982
# Epoch 332/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 540.4391 - categorical_accuracy: 0.2544
# Epoch 333/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 200.2760 - categorical_accuracy: 0.1842
# Epoch 334/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 1781.7487 - categorical_accuracy: 0.1754
# Epoch 335/1000
# 4/4 [==============================] - 0s 57ms/step - loss: 3118.5862 - categorical_accuracy: 0.1930
# Epoch 336/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 2121.7393 - categorical_accuracy: 0.2982
# Epoch 337/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 634.9987 - categorical_accuracy: 0.1754
# Epoch 338/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 874.1328 - categorical_accuracy: 0.1316
# Epoch 339/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1359.0730 - categorical_accuracy: 0.2895
# Epoch 340/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 738.2518 - categorical_accuracy: 0.2632
# Epoch 341/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 714.7181 - categorical_accuracy: 0.2632
# Epoch 342/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 543.4675 - categorical_accuracy: 0.3070
# Epoch 343/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 2094.8555 - categorical_accuracy: 0.2105
# Epoch 344/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 2494.4360 - categorical_accuracy: 0.2544
# Epoch 345/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 917.1566 - categorical_accuracy: 0.2193
# Epoch 346/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 1142.0446 - categorical_accuracy: 0.2368
# Epoch 347/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 333.8473 - categorical_accuracy: 0.2544
# Epoch 348/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 1178.3685 - categorical_accuracy: 0.2632
# Epoch 349/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 502.8024 - categorical_accuracy: 0.2456
# Epoch 350/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 3.4283 - categorical_accuracy: 0.2456
# Epoch 351/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 2.5992 - categorical_accuracy: 0.2368
# Epoch 352/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 2.2485 - categorical_accuracy: 0.2544
# Epoch 353/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 2.1515 - categorical_accuracy: 0.2544
# Epoch 354/1000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.0361 - categorical_accuracy: 0.2544
# Epoch 355/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 1.8538 - categorical_accuracy: 0.2544
# Epoch 356/1000
# 4/4 [==============================] - 0s 73ms/step - loss: 1.6891 - categorical_accuracy: 0.2544
# Epoch 357/1000
# 4/4 [==============================] - 0s 76ms/step - loss: 1.5856 - categorical_accuracy: 0.2544
# Epoch 358/1000
# 4/4 [==============================] - 0s 70ms/step - loss: 1.5045 - categorical_accuracy: 0.2544
# Epoch 359/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1.4460 - categorical_accuracy: 0.2544
# Epoch 360/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 1.3900 - categorical_accuracy: 0.2544
# Epoch 361/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1.3452 - categorical_accuracy: 0.2895
# Epoch 362/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 1.3105 - categorical_accuracy: 0.5789
# Epoch 363/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.2804 - categorical_accuracy: 0.6754
# Epoch 364/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.2531 - categorical_accuracy: 0.6754
# Epoch 365/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 1.2305 - categorical_accuracy: 0.6754
# Epoch 366/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 1.2106 - categorical_accuracy: 0.6754
# Epoch 367/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.1915 - categorical_accuracy: 0.6754
# Epoch 368/1000
# 4/4 [==============================] - 0s 57ms/step - loss: 1.1787 - categorical_accuracy: 0.6754
# Epoch 369/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 1.1715 - categorical_accuracy: 0.6842
# Epoch 370/1000
# 4/4 [==============================] - 0s 57ms/step - loss: 1.1611 - categorical_accuracy: 0.6667
# Epoch 371/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 1.1538 - categorical_accuracy: 0.6667
# Epoch 372/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 1.1490 - categorical_accuracy: 0.6667
# Epoch 373/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 1.1442 - categorical_accuracy: 0.6579
# Epoch 374/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1.1391 - categorical_accuracy: 0.6579
# Epoch 375/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 1.1347 - categorical_accuracy: 0.6667
# Epoch 376/1000
# 4/4 [==============================] - 0s 66ms/step - loss: 1.1298 - categorical_accuracy: 0.6930
# Epoch 377/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 1.1249 - categorical_accuracy: 0.6842
# Epoch 378/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 1.1212 - categorical_accuracy: 0.5702
# Epoch 379/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1.1151 - categorical_accuracy: 0.4649
# Epoch 380/1000
# 4/4 [==============================] - 0s 74ms/step - loss: 1.1101 - categorical_accuracy: 0.4649
# Epoch 381/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 1.1051 - categorical_accuracy: 0.4825
# Epoch 382/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 1.1000 - categorical_accuracy: 0.4737
# Epoch 383/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.0947 - categorical_accuracy: 0.4825
# Epoch 384/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1.0875 - categorical_accuracy: 0.4825
# Epoch 385/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.0789 - categorical_accuracy: 0.5000
# Epoch 386/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.0711 - categorical_accuracy: 0.6842
# Epoch 387/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 1.0616 - categorical_accuracy: 0.7281
# Epoch 388/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.0578 - categorical_accuracy: 0.6667
# Epoch 389/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1.0504 - categorical_accuracy: 0.6491
# Epoch 390/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1.0461 - categorical_accuracy: 0.6754
# Epoch 391/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 1.0433 - categorical_accuracy: 0.4825
# Epoch 392/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 1.0369 - categorical_accuracy: 0.4912
# Epoch 393/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 1.0323 - categorical_accuracy: 0.6491
# Epoch 394/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.0257 - categorical_accuracy: 0.7105
# Epoch 395/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 1.0209 - categorical_accuracy: 0.7281
# Epoch 396/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.0148 - categorical_accuracy: 0.7281
# Epoch 397/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 1.0072 - categorical_accuracy: 0.7281
# Epoch 398/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 1.0020 - categorical_accuracy: 0.7193
# Epoch 399/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.9943 - categorical_accuracy: 0.7281
# Epoch 400/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.9914 - categorical_accuracy: 0.7105
# Epoch 401/1000
# 4/4 [==============================] - 0s 57ms/step - loss: 0.9869 - categorical_accuracy: 0.7281
# Epoch 402/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.9830 - categorical_accuracy: 0.7018
# Epoch 403/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.9801 - categorical_accuracy: 0.7193
# Epoch 404/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.9744 - categorical_accuracy: 0.7193
# Epoch 405/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.9705 - categorical_accuracy: 0.7193
# Epoch 406/1000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.9664 - categorical_accuracy: 0.7281
# Epoch 407/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.9623 - categorical_accuracy: 0.7281
# Epoch 408/1000
# 4/4 [==============================] - 0s 72ms/step - loss: 0.9611 - categorical_accuracy: 0.7281
# Epoch 409/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 0.9553 - categorical_accuracy: 0.7193
# Epoch 410/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 0.9499 - categorical_accuracy: 0.7281
# Epoch 411/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.9425 - categorical_accuracy: 0.7281
# Epoch 412/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.9367 - categorical_accuracy: 0.7281
# Epoch 413/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.9336 - categorical_accuracy: 0.7281
# Epoch 414/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.9244 - categorical_accuracy: 0.7368
# Epoch 415/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.9232 - categorical_accuracy: 0.7544
# Epoch 416/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 0.9171 - categorical_accuracy: 0.7193
# Epoch 417/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 0.9118 - categorical_accuracy: 0.7982
# Epoch 418/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.9149 - categorical_accuracy: 0.6667
# Epoch 419/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.8992 - categorical_accuracy: 0.7632
# Epoch 420/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.8900 - categorical_accuracy: 0.7632
# Epoch 421/1000
# ...
# Epoch 427/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.7155 - categorical_accuracy: 0.9561
# Epoch 428/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.6916 - categorical_accuracy: 0.9737
# Epoch 429/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 0.6682 - categorical_accuracy: 0.9825
# Epoch 430/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.6521 - categorical_accuracy: 0.9737
# Epoch 431/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.6350 - categorical_accuracy: 0.9825
# Epoch 432/1000
# 4/4 [==============================] - 0s 66ms/step - loss: 0.6269 - categorical_accuracy: 0.9737
# Epoch 433/1000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.6110 - categorical_accuracy: 0.9737
# Epoch 434/1000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.6057 - categorical_accuracy: 0.9737
# Epoch 435/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.5940 - categorical_accuracy: 0.9825
# Epoch 436/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.5863 - categorical_accuracy: 0.9737
# Epoch 437/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.5715 - categorical_accuracy: 0.9737
# Epoch 438/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.5587 - categorical_accuracy: 0.9737
# Epoch 439/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 0.5510 - categorical_accuracy: 0.9737
# Epoch 440/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.5426 - categorical_accuracy: 0.9737
# Epoch 441/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 0.5323 - categorical_accuracy: 0.9737
# Epoch 442/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.5256 - categorical_accuracy: 0.9737
# Epoch 443/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.5164 - categorical_accuracy: 0.9737
# Epoch 444/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.5088 - categorical_accuracy: 0.9737
# Epoch 445/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.4984 - categorical_accuracy: 0.9737
# Epoch 446/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.4926 - categorical_accuracy: 0.9825
# Epoch 447/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.4882 - categorical_accuracy: 0.9737
# Epoch 448/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.4818 - categorical_accuracy: 0.9737
# Epoch 449/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 0.4793 - categorical_accuracy: 0.9737
# Epoch 450/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.4663 - categorical_accuracy: 0.9737
# Epoch 451/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.4618 - categorical_accuracy: 0.9737
# Epoch 452/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 0.4562 - categorical_accuracy: 0.9737
# Epoch 453/1000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.4524 - categorical_accuracy: 0.9737
# Epoch 454/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 0.4428 - categorical_accuracy: 0.9737
# Epoch 455/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.4400 - categorical_accuracy: 0.9737
# Epoch 456/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 0.4357 - categorical_accuracy: 0.9825
# Epoch 457/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.4311 - categorical_accuracy: 0.9912
# Epoch 458/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.4260 - categorical_accuracy: 0.9912
# Epoch 459/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.4245 - categorical_accuracy: 0.9737
# Epoch 460/1000
# 4/4 [==============================] - 0s 57ms/step - loss: 0.4239 - categorical_accuracy: 0.9737
# Epoch 461/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.4136 - categorical_accuracy: 0.9737
# Epoch 462/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.4107 - categorical_accuracy: 0.9825
# Epoch 463/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.4040 - categorical_accuracy: 0.9912
# Epoch 464/1000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.4002 - categorical_accuracy: 0.9912
# Epoch 465/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 0.3991 - categorical_accuracy: 0.9825
# Epoch 466/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.3964 - categorical_accuracy: 0.9825
# Epoch 467/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.3946 - categorical_accuracy: 0.9912
# Epoch 468/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.3906 - categorical_accuracy: 0.9825
# Epoch 469/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.3821 - categorical_accuracy: 0.9825
# Epoch 470/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.3799 - categorical_accuracy: 0.9825
# Epoch 471/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.3757 - categorical_accuracy: 0.9825
# Epoch 472/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.3739 - categorical_accuracy: 0.9825
# Epoch 473/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.3834 - categorical_accuracy: 0.9912
# Epoch 474/1000
# 4/4 [==============================] - 0s 57ms/step - loss: 0.3782 - categorical_accuracy: 0.9825
# Epoch 475/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 0.3735 - categorical_accuracy: 0.9825
# Epoch 476/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.3713 - categorical_accuracy: 0.9825
# Epoch 477/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.3613 - categorical_accuracy: 0.9912
# Epoch 478/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 0.3686 - categorical_accuracy: 0.9825
# Epoch 479/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.3582 - categorical_accuracy: 0.9825
# Epoch 480/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.3552 - categorical_accuracy: 0.9825
# Epoch 481/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.3474 - categorical_accuracy: 0.9825
# Epoch 482/1000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.3429 - categorical_accuracy: 0.9825
# Epoch 483/1000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.3451 - categorical_accuracy: 0.9825
# Epoch 484/1000
# 4/4 [==============================] - 0s 80ms/step - loss: 0.3390 - categorical_accuracy: 0.9912
# Epoch 485/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.3438 - categorical_accuracy: 0.9825
# Epoch 486/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.3364 - categorical_accuracy: 0.9825
# Epoch 487/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.3297 - categorical_accuracy: 0.9912
# Epoch 488/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.3272 - categorical_accuracy: 0.9825
# Epoch 489/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.3272 - categorical_accuracy: 0.9912
# Epoch 490/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.3323 - categorical_accuracy: 0.9825
# Epoch 491/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.3307 - categorical_accuracy: 0.9825
# Epoch 492/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.3341 - categorical_accuracy: 0.9825
# Epoch 493/1000
# 4/4 [==============================] - 0s 66ms/step - loss: 0.3347 - categorical_accuracy: 0.9825
# Epoch 494/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.3246 - categorical_accuracy: 0.9825
# Epoch 495/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.3097 - categorical_accuracy: 0.9825
# Epoch 496/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.2900 - categorical_accuracy: 1.0000
# Epoch 497/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.2442 - categorical_accuracy: 0.9825
# Epoch 498/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.2367 - categorical_accuracy: 0.9912
# Epoch 499/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.2393 - categorical_accuracy: 0.9912
# Epoch 500/1000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.2332 - categorical_accuracy: 0.9825
# Epoch 501/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.2513 - categorical_accuracy: 0.9825
# Epoch 502/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.2395 - categorical_accuracy: 0.9825
# Epoch 503/1000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.2189 - categorical_accuracy: 0.9912
# Epoch 504/1000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.2072 - categorical_accuracy: 1.0000
# Epoch 505/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 0.2232 - categorical_accuracy: 0.9825
# Epoch 506/1000
# 4/4 [==============================] - 0s 72ms/step - loss: 0.2084 - categorical_accuracy: 0.9912
# Epoch 507/1000
# 4/4 [==============================] - 0s 76ms/step - loss: 0.2004 - categorical_accuracy: 0.9912
# Epoch 508/1000
# 4/4 [==============================] - 0s 102ms/step - loss: 0.2031 - categorical_accuracy: 0.9912
# Epoch 509/1000
# 4/4 [==============================] - 0s 75ms/step - loss: 0.2047 - categorical_accuracy: 0.9912
# Epoch 510/1000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.2174 - categorical_accuracy: 0.9825
# Epoch 511/1000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.2050 - categorical_accuracy: 0.9825
# Epoch 512/1000
# 4/4 [==============================] - 0s 72ms/step - loss: 0.1930 - categorical_accuracy: 0.9912
# Epoch 513/1000
# 4/4 [==============================] - 0s 77ms/step - loss: 0.1904 - categorical_accuracy: 0.9912
# Epoch 514/1000
# 4/4 [==============================] - 0s 87ms/step - loss: 0.1830 - categorical_accuracy: 0.9912
# Epoch 515/1000
# 4/4 [==============================] - 0s 78ms/step - loss: 0.1878 - categorical_accuracy: 0.9912
# Epoch 516/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1742 - categorical_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/mohammedmaqdoom/Downloads/project/Action Detection Refined-2.ipynb Cell 37 line 1
# ----> <a href='vscode-notebook-cell:/Users/mohammedmaqdoom/Downloads/project/Action%20Detection%20Refined-2.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> model.fit(X_train, y_train, epochs=1000, callbacks=[tb_callback])
#
# File ~/Downloads/project/env/lib/python3.8/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Downloads/project/env/lib/python3.8/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/Downloads/project/env/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Downloads/project/env/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Downloads/project/env/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/Downloads/project/env/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/Downloads/project/env/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Downloads/project/env/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/Downloads/project/env/lib/python3.8/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/Downloads/project/env/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 596708 (2.28 MB)
# Trainable params: 596708 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 278ms/step

# %%
actions[np.argmax(res[1])]
# Out:
# 'Hello!'

# %%
actions[np.argmax(y_test[1])]
# Out:
# 'Hello!'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')
# Out:
# /Users/mohammedmaqdoom/Downloads/project/env/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[4, 0],
#         [0, 2]],
#
#        [[4, 0],
#         [0, 2]],
#
#        [[5, 0],
#         [0, 1]],
#
#        [[5, 0],
#         [0, 1]]])

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
# from itertools import cycle

# def prob_viz(res, actions, input_frame, colors):
#     output_frame = input_frame.copy()
#     color_cycle = cycle(colors)  # Create an infinite loop over colors

#     for num, prob in enumerate(res):
#         cv2.rectangle(output_frame, (0, 60+num*40), (int(prob*100), 90+num*40), next(color_cycle), -1)
#         cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

#     return output_frame

# %%
colors = [(255, 128, 64), (64, 224, 208), (238, 130, 238), (165, 42, 42), (160, 82, 45)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/mohammedmaqdoom/Downloads/project/Action Detection Refined-2.ipynb Cell 56 line 2
#       <a href='vscode-notebook-cell:/Users/mohammedmaqdoom/Downloads/project/Action%20Detection%20Refined-2.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(18,18))
# ----> <a href='vscode-notebook-cell:/Users/mohammedmaqdoom/Downloads/project/Action%20Detection%20Refined-2.ipynb#Y106sZmlsZQ%3D%3D?line=1'>2</a> plt.imshow(prob_viz(res, actions, image, colors))
#
# /Users/mohammedmaqdoom/Downloads/project/Action Detection Refined-2.ipynb Cell 56 line 5
#       <a href='vscode-notebook-cell:/Users/mohammedmaqdoom/Downloads/project/Action%20Detection%20Refined-2.ipynb#Y106sZmlsZQ%3D%3D?line=2'>3</a> output_frame = input_frame.copy()
#       <a href='vscode-notebook-cell:/Users/mohammedmaqdoom/Downloads/project/Action%20Detection%20Refined-2.ipynb#Y106sZmlsZQ%3D%3D?line=3'>4</a> for num, prob in enumerate(res):
# ----> <a href='vscode-notebook-cell:/Users/mohammedmaqdoom/Downloads/project/Action%20Detection%20Refined-2.ipynb#Y106sZmlsZQ%3D%3D?line=4'>5</a>     cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
#       <a href='vscode-notebook-cell:/Users/mohammedmaqdoom/Downloads/project/Action%20Detection%20Refined-2.ipynb#Y106sZmlsZQ%3D%3D?line=5'>6</a>     cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
#       <a href='vscode-notebook-cell:/Users/mohammedmaqdoom/Downloads/project/Action%20Detection%20Refined-2.ipynb#Y106sZmlsZQ%3D%3D?line=7'>8</a> return output_frame
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
sequence = []
sentence = []
threshold = 0.5
last_action = None
action_counts = {action: 0 for action in actions}
required_count = 10  # Number of consistent predictions required
cooldown = 20  # Frames to wait before allowing the same action again
cooldown_counter = 0

cap = cv2.VideoCapture(0)
# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        # Read feed
        ret, frame = cap.read()
        
        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            predicted_action_index = np.argmax(res)
            predicted_action = actions[predicted_action_index]
            print(predicted_action)
            
            if res[predicted_action_index] > threshold:
                action_counts[predicted_action] += 1
                for action in actions:
                    if action != predicted_action:
                        action_counts[action] = 0

                if action_counts[predicted_action] >= required_count:
                    if predicted_action != last_action and cooldown_counter == 0:
                        sentence.append(predicted_action)
                        last_action = predicted_action
                        cooldown_counter = cooldown
                        action_counts = {action: 0 for action in actions}

            if cooldown_counter > 0:
                cooldown_counter -= 1

            if len(sentence) > 7:
                sentence = sentence[-7:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
        
        cv2.rectangle(image, (0,0), (1340, 40), (255, 255, 255), -1)
        cv2.putText(image, ' '.join(sentence), (3,30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)
        
        # Break
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# I0000 00:00:1718288898.071865       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ...
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Hello!
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
cap.release()
cv2.destroyAllWindows()
